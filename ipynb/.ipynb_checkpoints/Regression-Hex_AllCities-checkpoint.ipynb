# %%
import sys
import json
from pathlib import Path
from dateutil import parser


import scipy
import statsmodels.formula.api as sm
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

DIR = Path('..')
sys.path.append(str(DIR))

import gtfstk as gt
import arcgdfconvertor as agc



DATA_DIR = DIR/'data/'
OUT_DIR = DIR/'output/'


# %load_ext autoreload
# %autoreload 2
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Binary Meshblock

# %%
#Read CSVs Binary

before_csv = "Auckland_Before_MB_Binary_summary.csv"
after_csv = "Auckland_After_MB_Binary_summary.csv"

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': str})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': str})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')
gdf = agc.fc_to_gdf(str(DATA_DIR/'Raw_data.gdb'/'MB2013_point'))

df = gdf.merge(access_df, left_on = 'Unique_ID', right_on = 'from', how = 'left').drop('from', axis =1)
cond = (df['hh_Income'] > 3) & (df['Pop_13'] > 3) & (df['P_O_W'] > 3)
df = df[cond].copy()

models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'hh_Income', 'pow_{0}before'.format(i), 'pow_{0}after'.format(i)]].copy()
    df2['diff'] = df2['pow_{0}after'.format(i)] - df2['pow_{0}before'.format(i)]
    cond = (df2['diff'] > 100)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    df2['diff_percentile'] = df2['diff'].rank(pct=True)
    df2['income_percentile'] = df['hh_Income'].rank(pct=True)

    p1 = scipy.stats.pearsonr(df2['diff_percentile'], df2['NZDep_per'])
    p2 = scipy.stats.pearsonr(df2['diff_percentile'], df2['income_percentile'])
    pearson01[i] = p1
    pearson02[i] = p2
    
#     model01 = sm.ols(formula="diff_percentile ~ NZDep_per", data=df2).fit()
#     model02 = sm.ols(formula="diff_percentile ~ income_percentile", data=df2).fit()
#     models01[i] = model01
#     models02[i] = model02

# %% [markdown]
# ### NZDep outputs

# %%
pearson = pd.DataFrame(pearson01).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff       Sig
# 20    0.115975  0.804435
# 25    0.357973  0.111090
# 30    0.054240  0.825453
# 35    0.400132  0.072287
# 40    0.375718  0.093255
# 45   -0.118341  0.651008
# 50    0.545371  0.043688
# 55    0.298205  0.189190
# 60    0.325274  0.150210

# %% [markdown]
# ### Income outputs

# %%
pearson = pd.DataFrame(pearson02).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff       Sig
# 20   -0.026991  0.954196
# 25   -0.249534  0.275335
# 30   -0.210951  0.385995
# 35   -0.339803  0.131789
# 40   -0.241758  0.291060
# 45   -0.279137  0.277922
# 50   -0.389837  0.168235
# 55   -0.753829  0.000079
# 60   -0.525776  0.014366

# %% [markdown]
# # Dist Decay Meshblock

# %%
#Read CSVs Dist_decay

before_csv = "Auckland_Before_MB_dist_decay_summary.csv"
after_csv = "Auckland_After_MB_dist_decay_summary.csv"
census_geom = str(DATA_DIR/'Raw_data.gdb'/'MB2013_point')

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': int})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': int})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')
gdf = agc.fc_to_gdf(census_geom)
gdf["Unique_ID"] = gdf["Unique_ID"].astype("int")

df = gdf.merge(access_df, left_on = 'Unique_ID', right_on = 'from', how = 'left').drop('from', axis =1)
cond = (df['hh_Income'] > 3) & (df['Pop_13'] > 3) & (df['P_O_W'] > 3)
df = df[cond].copy()

models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'hh_Income', 'dist_decay_{0}before'.format(i), 'dist_decay_{0}after'.format(i)]].copy()
    df2['diff'] = df2['dist_decay_{0}after'.format(i)] - df2['dist_decay_{0}before'.format(i)]
    cond = (df2['diff'] > 100)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    df2['diff_percentile'] = df2['diff'].rank(pct=True)
    df2['income_percentile'] = df['hh_Income'].rank(pct=True)

    p1 = scipy.stats.pearsonr(df2['diff_percentile'], df2['NZDep_per'])
    p2 = scipy.stats.pearsonr(df2['diff_percentile'], df2['income_percentile'])
    pearson01[i] = p1
    pearson02[i] = p2
    
#     model01 = sm.ols(formula="diff_percentile ~ NZDep_per", data=df2).fit()
#     model02 = sm.ols(formula="diff_percentile ~ income_percentile", data=df2).fit()
#     models01[i] = model01
#     models02[i] = model02

# %% [markdown]
# ### NZDep outputs

# %%
pearson = pd.DataFrame(pearson01).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff       Sig
# 20   -0.042291  0.173361
# 25    0.102156  0.059883
# 30    0.141744  0.130770
# 35    0.190851  0.155003
# 40    0.251156  0.078520
# 45    0.248159  0.089001
# 50    0.050924  0.745710
# 55    0.035575  0.829765
# 60    0.111606  0.487242

# %% [markdown]
# ### Income outputs

# %%
pearson = pd.DataFrame(pearson02).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff  Sig
# 20         NaN  1.0
# 25         NaN  1.0
# 30         NaN  1.0
# 35         NaN  1.0
# 40         NaN  1.0
# 45         NaN  1.0
# 50         NaN  1.0
# 55         NaN  1.0
# 60         NaN  1.0

# %% [markdown]
# # Binary Hex

# %%
#Read CSVs Dist_decay

before_csv = "Auckland_Before_Hex_Binary_summary.csv"
after_csv = "Auckland_After_Hex_Binary_summary.csv"
census_geom = str(DATA_DIR/'Raw_data.gdb'/'Auckland_Hex_Point')

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': str})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': str})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')
gdf = agc.fc_to_gdf(census_geom)

df = gdf.merge(access_df, left_on = 'Unique_ID', right_on = 'from', how = 'left').drop('from', axis =1)
cond = (df['hh_Income'] > 3) & (df['Pop_13'] > 3) & (df['P_O_W'] > 3)
df = df[cond].copy()

models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'hh_Income', 'pow_{0}before'.format(i), 'pow_{0}after'.format(i)]].copy()
    df2['diff'] = df2['pow_{0}after'.format(i)] - df2['pow_{0}before'.format(i)]
    cond = (df2['diff'] >= 0)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    df2['diff_percentile'] = df2['diff'].rank(pct=True)
    df2['income_percentile'] = df['hh_Income'].rank(pct=True)

    p1 = scipy.stats.pearsonr(df2['diff_percentile'], df2['NZDep_per'])
    p2 = scipy.stats.pearsonr(df2['diff_percentile'], df2['income_percentile'])
    pearson01[i] = p1
    pearson02[i] = p2

# %%
pearson = pd.DataFrame(pearson01).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20    0.097258  9.950453e-02
# 25    0.252048  9.919227e-06
# 30    0.304147  9.903524e-08
# 35    0.309604  8.155237e-08
# 40    0.306193  1.725190e-07
# 45    0.368414  2.886048e-10
# 50    0.397119  5.627654e-12
# 55    0.416639  2.875365e-13
# 60    0.345677  2.994829e-09

# %%
pearson = pd.DataFrame(pearson02).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20   -0.072779  2.181862e-01
# 25   -0.194802  6.924774e-04
# 30   -0.177461  2.217991e-03
# 35   -0.149703  1.096377e-02
# 40   -0.130180  2.941641e-02
# 45   -0.189208  1.622203e-03
# 50   -0.237896  5.980627e-05
# 55   -0.322236  3.102018e-08
# 60   -0.300150  3.233957e-07

# %% [markdown]
# # Dist Decay Hex

# %%
#Read CSVs Dist_decay

before_csv = "Auckland_Before_Hex_dist_decay_summary.csv"
after_csv = "Auckland_After_Hex_dist_decay_summary.csv"
census_geom = str(DATA_DIR/'Raw_data.gdb'/'Auckland_Hex_Point')

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': str})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': str})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')
gdf = agc.fc_to_gdf(census_geom)

df = gdf.merge(access_df, left_on = 'Unique_ID', right_on = 'from', how = 'left').drop('from', axis =1)
cond = (df['hh_Income'] > 3) & (df['Pop_13'] > 3) & (df['P_O_W'] > 3)
df = df[cond].copy()

models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'hh_Income', 'dist_decay_{0}before'.format(i), 'dist_decay_{0}after'.format(i)]].copy()
    df2['diff'] = df2['dist_decay_{0}after'.format(i)] - df2['dist_decay_{0}before'.format(i)]
    cond = (df2['diff'] > 100)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    df2['diff_percentile'] = df2['diff'].rank(pct=True)
    df2['income_percentile'] = df['hh_Income'].rank(pct=True)

    p1 = scipy.stats.pearsonr(df2['diff_percentile'], df2['NZDep_per'])
    p2 = scipy.stats.pearsonr(df2['diff_percentile'], df2['income_percentile'])
    pearson01[i] = p1
    pearson02[i] = p2

# %%
pearson = pd.DataFrame(pearson01).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20   -0.021602  7.843126e-01
# 25    0.028246  6.996297e-01
# 30    0.066426  3.312125e-01
# 35    0.115525  7.908699e-02
# 40    0.184642  3.325206e-03
# 45    0.289117  1.941523e-06
# 50    0.345292  7.299314e-09
# 55    0.382751  5.025547e-11
# 60    0.365312  1.859416e-10

# %%
pearson = pd.DataFrame(pearson02).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20    0.109526  1.639946e-01
# 25    0.102334  1.611524e-01
# 30    0.068399  3.170226e-01
# 35   -0.004856  9.413566e-01
# 40   -0.044307  4.846788e-01
# 45   -0.166262  6.994429e-03
# 50   -0.231721  1.370143e-04
# 55   -0.295290  6.159213e-07
# 60   -0.313274  6.247674e-08

# %% [markdown]
# # Binary AU

# %%
#Read CSVs Dist_decay

before_csv = "Auckland_After_AU_Binary_summary.csv"
after_csv = "Auckland_Before_AU_Binary_summary.csv"
census_geom = str(DATA_DIR/'Raw_data.gdb'/'AU2013_point')

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': str})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': str})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')
gdf = agc.fc_to_gdf(census_geom)

df = gdf.merge(access_df, left_on = 'Unique_ID', right_on = 'from', how = 'left').drop('from', axis =1)
cond = (df['HH_Income_13'] > 3) & (df['Pop_2013'] > 3) & (df['P_O_W'] > 3)
df = df[cond].copy()

models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'HH_Income_13', 'pow_{0}before'.format(i), 'pow_{0}after'.format(i)]].copy()
    df2['diff'] = df2['pow_{0}after'.format(i)] - df2['pow_{0}before'.format(i)]
    cond = (df2['diff'] > 0)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    df2['diff_percentile'] = df2['diff'].rank(pct=True)
    df2['income_percentile'] = df['HH_Income_13'].rank(pct=True)

    p1 = scipy.stats.pearsonr(df2['diff_percentile'], df2['NZDep_per'])
    p2 = scipy.stats.pearsonr(df2['diff_percentile'], df2['income_percentile'])
    pearson01[i] = p1
    pearson02[i] = p2

# %%
models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'HH_Income_13', 'pow_{0}before'.format(i), 'pow_{0}after'.format(i)]].copy()
    df2['diff'] = df2['pow_{0}after'.format(i)] - df2['pow_{0}before'.format(i)]
    cond = (df2['diff'] >= 0)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    df2['diff_percentile'] = df2['diff'].rank(pct=True)
    df2['income_percentile'] = df['HH_Income_13'].rank(pct=True)

    p1 = scipy.stats.pearsonr(df2['diff_percentile'], df2['NZDep_per'])
    p2 = scipy.stats.pearsonr(df2['diff_percentile'], df2['income_percentile'])
    pearson01[i] = p1
    pearson02[i] = p2

# %%
pearson = pd.DataFrame(pearson01).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20    0.061968  3.094450e-01
# 25    0.163160  5.678908e-03
# 30    0.248116  2.771452e-05
# 35    0.271289  4.817625e-06
# 40    0.274087  3.655482e-06
# 45    0.316180  9.937120e-08
# 50    0.378807  1.960020e-10
# 55    0.386591  5.532709e-11
# 60    0.418426  1.176598e-12

# %%
pearson = pd.DataFrame(pearson02).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20   -0.006357  9.170314e-01
# 25   -0.110884  6.109813e-02
# 30   -0.157724  8.309722e-03
# 35   -0.146167  1.508394e-02
# 40   -0.150873  1.193423e-02
# 45   -0.232037  1.124271e-04
# 50   -0.303695  4.895904e-07
# 55   -0.362157  9.981566e-10
# 60   -0.344870  8.147157e-09

# %% [markdown]
# # Dist Decay AU

# %%
#Read CSVs Dist_decay

before_csv = "Auckland_After_AU_dist_decay_summary.csv"
after_csv = "Auckland_Before_AU_dist_decay_summary.csv"
census_geom = str(DATA_DIR/'Raw_data.gdb'/'AU2013_point')

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': str})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': str})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')
gdf = agc.fc_to_gdf(census_geom)

df = gdf.merge(access_df, left_on = 'Unique_ID', right_on = 'from', how = 'left').drop('from', axis =1)
cond = (df['HH_Income_13'] > 3) & (df['Pop_2013'] > 3) & (df['P_O_W'] > 3)
df = df[cond].copy()

models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'HH_Income_13', 'dist_decay_{0}before'.format(i), 'dist_decay_{0}after'.format(i)]].copy()
    df2['diff'] = df2['dist_decay_{0}after'.format(i)] - df2['dist_decay_{0}before'.format(i)]
    cond = (df2['diff'] > 100)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    df2['diff_percentile'] = df2['diff'].rank(pct=True)
    df2['income_percentile'] = df['HH_Income_13'].rank(pct=True)

    p1 = scipy.stats.pearsonr(df2['diff_percentile'], df2['NZDep_per'])
    p2 = scipy.stats.pearsonr(df2['diff_percentile'], df2['income_percentile'])
    pearson01[i] = p1
    pearson02[i] = p2

# %%
pearson = pd.DataFrame(pearson01).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20    0.003317  9.651465e-01
# 25   -0.035421  6.149930e-01
# 30    0.048486  4.682762e-01
# 35    0.173732  6.977154e-03
# 40    0.258062  2.713735e-05
# 45    0.297106  6.019711e-07
# 50    0.362481  7.207384e-10
# 55    0.412724  8.889960e-13
# 60    0.450127  3.176821e-15

# %%
pearson = pd.DataFrame(pearson02).T
pearson.columns = ['Corr_Coeff', 'Sig']
pearson
# Out:
#     Corr_Coeff           Sig
# 20    0.060911  4.219372e-01
# 25    0.083690  2.340158e-01
# 30    0.030384  6.495867e-01
# 35   -0.092687  1.522890e-01
# 40   -0.183754  3.051906e-03
# 45   -0.245310  4.317610e-05
# 50   -0.317589  8.655365e-08
# 55   -0.380488  6.148601e-11
# 60   -0.417543  4.112187e-13

# %% [markdown]
# # Gini

# %%
def gini(x):
    # (Warning: This is a concise implementation, but it is O(n**2)
    # in time and memory, where n = len(x).  *Don't* pass in huge
    # samples!)

    # Mean absolute difference
    mad = np.abs(np.subtract.outer(x, x)).mean()
    # Relative mean absolute difference
    rmad = mad/np.mean(x)
    # Gini coefficient
    g = 0.5 * rmad
    return g

# %% [markdown]
# ### Gini MB

# %%
before_csv = "Auckland_After_MB_dist_decay_summary.csv"
after_csv = "Auckland_Before_MB_dist_decay_summary.csv"

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': str})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': str})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')

access_df = access_df.fillna(0)
a = list(access_df.columns.values)
a.remove('from')
access_df[a].apply(gini).to_frame()
# Out:
#                             0
# dist_decay_15before  0.612989
# dist_decay_20before  0.588919
# dist_decay_25before  0.560187
# dist_decay_30before  0.526951
# dist_decay_35before  0.490152
# dist_decay_40before  0.451659
# dist_decay_45before  0.413989
# dist_decay_50before  0.379588
# dist_decay_55before  0.350855
# dist_decay_60before  0.330093
# dist_decay_15after   0.607898
# dist_decay_20after   0.583087
# dist_decay_25after   0.554869
# dist_decay_30after   0.523959
# dist_decay_35after   0.491078
# dist_decay_40after   0.457359
# dist_decay_45after   0.424007
# dist_decay_50after   0.392795
# dist_decay_55after   0.366367
# dist_decay_60after   0.347294

# %%
before_csv = "Auckland_Before_MB_Binary_summary.csv"
after_csv = "Auckland_After_MB_Binary_summary.csv"

before_csv_path = OUT_DIR/"Auckland ouputs"/before_csv
after_csv_path = OUT_DIR/"Auckland ouputs"/after_csv

before_df = pd.read_csv(before_csv_path, index_col=0, dtype = {'from': str})
after_df = pd.read_csv(after_csv_path, index_col=0, dtype = {'from': str})

access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')

access_df = access_df.fillna(0)
a = list(access_df.columns.values)
a.remove('from')
access_df[a].apply(gini).to_frame()
# Out:
#                      0
# pow_15before  0.710971
# pow_20before  0.670144
# pow_25before  0.633783
# pow_30before  0.592266
# pow_35before  0.550861
# pow_40before  0.508142
# pow_45before  0.466281
# pow_50before  0.419380
# pow_55before  0.376798
# pow_60before  0.327335
# pow_15after   0.712570
# pow_20after   0.676477
# pow_25after   0.643772
# pow_30after   0.604920
# pow_35after   0.561026
# pow_40after   0.509597
# pow_45after   0.459250
# pow_50after   0.408550
# pow_55after   0.358242
# pow_60after   0.308185

# %%
coeff_list = [models02[i].params.to_frame().T for i in range(20, 65, 5)]
coeff_df = pd.concat(coeff_list).reset_index(drop = True)
coeff_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])
coeff_df
# Out:
#    Intercept  income_percentile  travel_time
# 0   0.487239           0.026964           20
# 1   0.473160           0.055533           25
# 2   0.508024          -0.015993           30
# 3   0.495459           0.009853           35
# 4   0.519573          -0.040910           40
# 5   0.524795          -0.051747           45
# 6   0.569862          -0.142065           50
# 7   0.556952          -0.116109           55
# 8   0.559595          -0.123419           60

# %%
coeff_list = [models01[i].params.to_frame().T for i in range(20, 65, 5)]
coeff_df = pd.concat(coeff_list).reset_index(drop = True)
coeff_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])
coeff_df

# %%
coeff_list = [models02[i].params.to_frame().T for i in range(20, 65, 5)]
coeff_df = pd.concat(coeff_list).reset_index(drop = True)
coeff_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])
coeff_df

# %%
models01 = dict()
models02 = dict()
pearson01 = dict()
pearson02 = dict()
for i in range(20, 65, 5):
    df2 = df[['NZDep_per', 'pow_{0}before'.format(i), 'pow_{0}after'.format(i)]].copy()
    df2['diff'] = df2['pow_{0}after'.format(i)] - df2['pow_{0}before'.format(i)]
    cond = (df2['diff'] > 100)#|(df2['diff'] < 100)
    df2 = df2[cond].copy()
    reg_df['diff_percentile'] = reg_df['diff'].rank(pct=True)
    df2['pow_{0}before_percentile'.format(i)] = df2['pow_{0}before'.format(i)].rank(pct=True)
    df2['pow_{0}after_percentile'.format(i)] = df2['pow_{0}after'.format(i)].rank(pct=True)
    p1 = scipy.stats.pearsonr(df2['pow_{0}before_percentile'], df2['pow_60after_percentile'])
    p2 = scipy.stats.pearsonr(df2['pow_{0}after_percentile'], df2['pow_60after_percentile'])
    
    model01 = sm.ols(formula="pow_{0}before_percentile ~ NZDep_per".format(i), data=df2).fit()
    model02 = sm.ols(formula="pow_{0}after_percentile ~ NZDep_per".format(i), data=df2).fit()
    models01[i] = model01
    models02[i] = model02

# %%
model02.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ...
# Dep. Variable:     dist_decay_45after_percentile   R-squared:                       0.009
# Model:                                       OLS   Adj. R-squared:                  0.009
# Method:                            Least Squares   F-statistic:                     60.96
# Date:                           Mon, 19 Feb 2018   Prob (F-statistic):           6.73e-15
# Time:                                   21:42:52   Log-Likelihood:                -1124.4
# No. Observations:                           6543   AIC:                             2253.
# Df Residuals:                               6541   BIC:                             2266.
# Df Model:                                      1
# Covariance Type:                       nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
models1 = dict()
models2 = dict()
for i in range(20, 65, 5):
    reg_df = df.copy()
    reg_df['diff'] = reg_df['dist_decay_{0}after'.format(i)] - reg_df['dist_decay_{0}before'.format(i)]
    cond = (reg_df['diff'] > 3)|(reg_df['diff'] < 3)
    reg_df = reg_df[cond].copy()
    #reg_df['ln_diff']= np.log(reg_df['diff'])
    reg_df['diff_percentile'] = reg_df['diff'].rank(pct=True)
    #y = reg_df['diff_percentile']
    #x = reg_df[['ln_income', 'ln_pop_density', 'ln_job_density']]
    # Note the difference in argument order
    model1 = sm.ols(formula="diff ~ {0}".format(HH_Income), data=reg_df).fit()
    models1[i]= model1
    model2 = sm.ols(formula="diff_percentile ~ NZDep_per", data=reg_df).fit()
    models2[i]= model2

# %%
coeff_list = [models1[i].params.to_frame().T for i in range(20, 65, 5)]
coeff_df = pd.concat(coeff_list).reset_index(drop = True)
coeff_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])

conf_list = [models1[i].conf_int().T[[HH_Income]].T for i in range(20, 65, 5)]
conf_df = pd.concat(conf_list).reset_index(drop = True)
conf_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])

output_df1 = coeff_df[[HH_Income]].join(conf_df)

coeff_list = [models2[i].params.to_frame().T for i in range(20, 65, 5)]
coeff_df = pd.concat(coeff_list).reset_index(drop = True)
coeff_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])

conf_list = [models2[i].conf_int().T[['NZDep_per']].T for i in range(20, 65, 5)]
conf_df = pd.concat(conf_list).reset_index(drop = True)
conf_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])

pvalues_list = [models2[i].pvalues.to_frame().T for i in range(20, 65, 5)]
pvalues_df = pd.concat(pvalues_list).reset_index(drop = True)
pvalues_df = pvalues_df[['NZDep_per']].copy()
pvalues_df.columns = ['pValue']


output_df2 = coeff_df[['NZDep_per']].join(conf_df)
output_df2 = output_df2.join(pvalues_df)

# %%
output = output_df1.merge(output_df2, right_on = 'travel_time', left_on = 'travel_time', suffixes = ['Income', 'NZDep'])
output.to_csv(r'D:\New folder (2)\temp.csv')
output
# Out:
#    hh_Income   0Income   1Income  travel_time  NZDep_per    0NZDep   1NZDep  \
# 0   0.002456 -0.000029  0.004942           20  -0.257826 -0.365422 -0.15023
# 1   0.002456 -0.000029  0.004942           25  -0.257826 -0.365422 -0.15023
# 2   0.002456 -0.000029  0.004942           30  -0.257826 -0.365422 -0.15023
# 3   0.002456 -0.000029  0.004942           35  -0.257826 -0.365422 -0.15023
# 4   0.002456 -0.000029  0.004942           40  -0.257826 -0.365422 -0.15023
# 5   0.002456 -0.000029  0.004942           45  -0.257826 -0.365422 -0.15023
# 6   0.002456 -0.000029  0.004942           50  -0.257826 -0.365422 -0.15023
# 7   0.002456 -0.000029  0.004942           55  -0.257826 -0.365422 -0.15023
# 8   0.002456 -0.000029  0.004942           60  -0.257826 -0.365422 -0.15023
#
#      pValue
# 0  0.000004
# 1  0.000004
# 2  0.000004
# 3  0.000004
# 4  0.000004
# 5  0.000004
# 6  0.000004
# 7  0.000004
# 8  0.000004

# %%
df = df.fillna(0)

# %%
fields = list()
for f in df.columns.values:
    if 'pow_' in f:
        fields.append(f)
        df['decile_'+f] = pd.to_numeric(df[f].rank(pct=True)*10).astype(int)

# %%
outs = list()
for f in df.columns.values:
    if 'decile_pow_' in f:
        fields.append(f)
        outs.append(df.groupby(f)[f.split("_",1)[1]].mean())

# %%
c = pd.concat(outs, axis =1)
c
# Out:
#     pow_15before  pow_20before  pow_25before   pow_30before   pow_35before  \
# 0     161.085366    368.560976    689.522205    1356.577982    2431.260274
# 1     367.915385    872.510769   1847.853659    3519.403670    6246.441718
# 2     538.812883   1333.639695   2926.313364    5638.242331    9432.836141
# 3     729.996965   1869.690549   3884.749240    7528.045662   12483.160550
# 4     986.083969   2505.541284   5017.952527    9662.761103   16825.009174
# 5    1334.087558   3262.527607   6674.203053   12838.204580   22169.427481
# 6    1753.628049   4357.737805   9045.785605   17363.519084   29464.067176
# 7    2443.740458   6116.779817  12485.697710   24463.708397   43456.770642
# 8    4065.678899   9798.554198  19905.963303   41302.787136   79540.857798
# 9   21212.651376  41258.784733  70793.601527  109725.590840  140207.111450
# 10  84366.000000           NaN           NaN            NaN            NaN
#
# ...

# %%
c.T
# Out:
#                         0             1             2              3   \
# pow_15before    161.085366    367.915385    538.812883     729.996965
# pow_20before    368.560976    872.510769   1333.639695    1869.690549
# pow_25before    689.522205   1847.853659   2926.313364    3884.749240
# pow_30before   1356.577982   3519.403670   5638.242331    7528.045662
# pow_35before   2431.260274   6246.441718   9432.836141   12483.160550
# pow_40before   4014.155963  10232.381679  15545.073394   20730.055046
# pow_45before   6676.488515  15634.804511  23997.886154   33565.830508
# pow_50before   9922.539171  23131.477204  35273.058193   49188.670807
# pow_55before  14320.344037  34938.981651  49969.111280   72053.136364
# pow_60before  20782.595166  51673.956522  81378.754545  112257.612903
# pow_15after     161.940639    373.347692    552.547945     745.661538
# pow_20after     369.334862    886.720183   1372.805513    1936.167173
# ...

# %%
c.to_csv(r"D:\New folder (2)\out2.csv")

# %%
out = df.groupby('decile', as_index=False)[fields].mean()
out =out.T
out['diff'] = out[9]-out[0]
out
#out.to_csv(r'D:\New folder (2)\out.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-287-4e38256e9821> in <module>()
# ----> 1 out = df.groupby('decile', as_index=False)[fields].mean()
#       2 out =out.T
#       3 out['diff'] = out[9]-out[0]
#       4 out
#       5 #out.to_csv(r'D:\New folder (2)\out.csv')
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ...

# %%
access_df.hist(column=['pow_45before', 'pow_45after'], bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CEBF832AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CEC4620B70>]], dtype=object)

# %%
x = access_df.pow_45before
y = access_df.pow_45after

#bins = numpy.linspace(-10, 10, 100)

plt.hist(x, 50, alpha=0.5, label='45 min access before CRL')
plt.hist(y, 50, alpha=0.5, label='45 min access after CRL')
plt.legend(loc='upper right')
plt.show()

# %%
test = 'ACPBC Network Maps_snapshots_180313_1149.kmz/ACPBC Network Maps_snapshots/2017/Non-AAA/Non-AAA_2017'
def a(f):
    l = f.split('/')
    if len(l)>3:
        return l[3]
    else:
        return ' '
a(test)
# Out:
# 'Non-AAA'

# %%
def gini(x):
    # (Warning: This is a concise implementation, but it is O(n**2)
    # in time and memory, where n = len(x).  *Don't* pass in huge
    # samples!)

    # Mean absolute difference
    mad = np.abs(np.subtract.outer(x, x)).mean()
    # Relative mean absolute difference
    rmad = mad/np.mean(x)
    # Gini coefficient
    g = 0.5 * rmad
    return g

# %%
access_df = before_df.merge(after_df, left_on = 'from', right_on = 'from', suffixes = ['before', 'after'], how = 'inner')
access_df = access_df.fillna(0)
a = list(access_df.columns.values)
a.remove('from')
access_df[a].apply(gini).to_csv(r'D:\New folder (2)\gini.csv')

# %%
ginis_before = dict()
ginis_before = dict()
for f in access_df.columns.values:
    if 'dist_decay' in f:
        ginis[f] = gini(access_df[f])

# %%
pd.DataFrame(ginis, index = [0])
# Out:
#    dist_decay_15after  dist_decay_15before  dist_decay_20after  \
# 0            0.617512             0.608067            0.593531
#
#    dist_decay_20before  dist_decay_25after  dist_decay_25before  \
# 0             0.583319            0.564213             0.555157
#
#    dist_decay_30after  dist_decay_30before  dist_decay_35after  \
# 0            0.529893             0.524286             0.49204
#
#    dist_decay_35before  dist_decay_40after  dist_decay_40before  \
# 0             0.491422             0.45289             0.457704
#
#    dist_decay_45after  dist_decay_45before  dist_decay_50after  \
# 0            0.414893             0.424328            0.380153
#
#    dist_decay_50before  dist_decay_55after  dist_decay_55before  \
# 0             0.393054            0.350872             0.366554
#
#    dist_decay_60after  dist_decay_60before
# 0            0.329413             0.347445

# %%
bins, result, gini_val = G(v)
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(0.1, result, label="observed")
plt.plot(bins, bins, '--', label="perfect eq.")
plt.xlabel("fraction of population")
plt.ylabel("fraction of wealth")
plt.title("GINI: %.4f" %(gini_val))
plt.legend()
plt.subplot(2, 1, 2)
plt.hist(v, bins=20)

# %%
after_df.hist(column='pow_45', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CEC1B75588>]], dtype=object)

# %%
output.to_csv(r'D:\New folder\reg_output.csv')

# %%
coeff_list = [models[i].params.to_frame().T for i in range(20, 65, 5)]
coeff_df = pd.concat(coeff_list).reset_index(drop = True)
coeff_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])
coeff_df
# Out:
#    Intercept  HH_Income_13  travel_time
# 0 -831.25031      0.005464           20
# 1 -831.25031      0.005464           25
# 2 -831.25031      0.005464           30
# 3 -831.25031      0.005464           35
# 4 -831.25031      0.005464           40
# 5 -831.25031      0.005464           45
# 6 -831.25031      0.005464           50
# 7 -831.25031      0.005464           55
# 8 -831.25031      0.005464           60

# %%
pvalues_list = [models[i].pvalues.to_frame().T for i in range(20, 65, 5)]
pvalues_df = pd.concat(pvalues_list).reset_index(drop = True)
pvalues_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])
pvalues_df
# Out:
#       Intercept  HH_Income_13  travel_time
# 0  4.160084e-09      0.001565           20
# 1  4.160084e-09      0.001565           25
# 2  4.160084e-09      0.001565           30
# 3  4.160084e-09      0.001565           35
# 4  4.160084e-09      0.001565           40
# 5  4.160084e-09      0.001565           45
# 6  4.160084e-09      0.001565           50
# 7  4.160084e-09      0.001565           55
# 8  4.160084e-09      0.001565           60

# %%
stderr_list = [models[i].bse.to_frame().T for i in range(20, 65, 5)]
stderr_df = pd.concat(stderr_list).reset_index(drop = True)
stderr_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])
stderr_df
# Out:
#    Intercept  HH_Income_13  travel_time
# 0  137.51265      0.001713           20
# 1  137.51265      0.001713           25
# 2  137.51265      0.001713           30
# 3  137.51265      0.001713           35
# 4  137.51265      0.001713           40
# 5  137.51265      0.001713           45
# 6  137.51265      0.001713           50
# 7  137.51265      0.001713           55
# 8  137.51265      0.001713           60

# %%
conf_list = [models[i].conf_int().T[['HH_Income_13']].T for i in range(20, 65, 5)]
conf_df = pd.concat(conf_list).reset_index(drop = True)
conf_df['travel_time'] = pd.Series([i for i in range(20, 65, 5)])
conf_df
# Out:
#           0         1  travel_time
# 0  0.002094  0.008835           20
# 1  0.002094  0.008835           25
# 2  0.002094  0.008835           30
# 3  0.002094  0.008835           35
# 4  0.002094  0.008835           40
# 5  0.002094  0.008835           45
# 6  0.002094  0.008835           50
# 7  0.002094  0.008835           55
# 8  0.002094  0.008835           60

# %%
output_df = coeff_df[['HH_Income_13']].join(conf_df)
output_df
# Out:
#    HH_Income_13         0         1  travel_time
# 0      0.005464  0.002094  0.008835           20
# 1      0.005464  0.002094  0.008835           25
# 2      0.005464  0.002094  0.008835           30
# 3      0.005464  0.002094  0.008835           35
# 4      0.005464  0.002094  0.008835           40
# 5      0.005464  0.002094  0.008835           45
# 6      0.005464  0.002094  0.008835           50
# 7      0.005464  0.002094  0.008835           55
# 8      0.005464  0.002094  0.008835           60

# %%
coeff_df.to_csv(str(OUT_DIR/'Auckland_Hex_coeff_df.csv'))
pvalues_df.to_csv(str(OUT_DIR/'Auckland_Hex_pvalues_df.csv'))
stderr_df.to_csv(str(OUT_DIR/'Auckland_Hex_stderr_df.csv'))
conf_df.to_csv(str(OUT_DIR/'Auckland_Hex_conf_df.csv'))
