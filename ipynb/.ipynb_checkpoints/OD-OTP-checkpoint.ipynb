# %%
import sys
import json
from pathlib import Path
from dateutil import parser
from math import pi

import requests
from shapely.geometry import shape, Point
import geopandas as gpd
import pandas as pd
import numpy as np


DIR = Path('..')
sys.path.append(str(DIR))

import gtfstk as gt
import pyotp as otp
import arcgdfconvertor as agc
import gtfsanalyst as ga


DATA_DIR = DIR/'data/'
OUT_DIR = DIR/'output/'


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Calculate OD

# %%
# setting the analysis date and time
dt = parser.parse('11/Jan/2018 8:00:00 AM')
in_gdf = agc.fc_to_gdf(str(DATA_DIR/'Raw_data.gdb'/'MB2013_point'))
in_gdf.head()
# Out:
#   Unique_ID  AU2013     AU2013_NAM  Pop_13  P_O_W  hh_Income  ORIG_FID  \
# 0   0147400  507500  Campbells Bay   102.0   18.0    77500.0         1
# 1   0147500  507500  Campbells Bay   231.0   21.0   150000.0         2
# 2   0147600  507500  Campbells Bay   204.0   30.0   141700.0         3
# 3   0147700  507500  Campbells Bay    99.0    6.0   112500.0         4
# 4   0147800  507500  Campbells Bay    81.0    6.0   125000.0         5
#
#                                        geometry
# 0  POINT (174.7574130310001 -36.74586689499995)
# 1  POINT (174.7553198190001 -36.74822094199993)
# 2      POINT (174.755949405 -36.74979134999995)
# 3  POINT (174.7584070520001 -36.74913251199996)
# 4  POINT (174.7586563360001 -36.74742249599996)

# %%
od_matrix = otp.od_matrix_unlimited(in_gdf, in_gdf, 'multimodal', 'Unique_ID', 'Unique_ID', dt)
# Out:
# Analysis started at: 2018-02-17 12:07:43.990350
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f2024562f844> in <module>()
# ----> 1 od_matrix = otp.od_matrix_unlimited(in_gdf, in_gdf, 'multimodal', 'Unique_ID', 'Unique_ID', dt)
#
# D:\Saeid\Google Drive\GitHub\Papers\FrequencyIsJustice\pyotp\pyotp.py in od_matrix_unlimited(origins, destinations, mode, origins_name, destinations_name, date_time, control_vars)
#     255                 mode='TRANSIT,WALK',
#     256                 trip_name = 'from {0} to {1}'.format(o[2], d[2]),
# --> 257                 date_time = date_time)
#     258             od_list.append(r)
#     259             cnt += 1
#
# D:\Saeid\Google Drive\GitHub\Papers\FrequencyIsJustice\pyotp\pyotp.py in route(locations_gdf, mode, trip_name, date_time, control_vars)
#      86         "locale":"en"}
#      87
# ---> 88     r = requests.get(url, params=query)
#      89
#      90     #if error then return emptly GeoDataFrame
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
od_matrix.head()

# %%
od_matrix['trip_id'] = od_matrix['trip_id'].str.replace('1:', '')
od_matrix['from_name'] = od_matrix['from_name'].str.replace('1:', '')
od_matrix.to_csv(str(OUT_DIR/'Auckland_MB_beforeCRL_detailed_od.csv'))

# %%
od_matrix.head(2).T

# %% [markdown]
# ## Calculate awt

# %%
# Load a feed
#
feed = gt.read_gtfs(DATA_DIR/'gtfs feeds'/'Auckland_GTFS.zip', dist_units='km')
feed

# %%
pt_edges = ga.pt_edges(
    ga.validate_feed(feed, '20180111'),
    max_cuf_off = 2 * 3600, 
    analysis_start = ga.text2sec('07:00:00'),
    analysis_end = ga.text2sec('09:00:00'), 
    convert_to_gpd = False)
pt_edges.head(2).T
# Out:
#                                                                      0  \
# trip_id                                1985054051-20171218162726_v61.9
# o_time                                                        09:30:00
# departure_time                                                09:30:00
# o_stop                                       4569-20171218162726_v61.9
# o_sequence                                                           1
# stop_headsign                                                        0
# pickup_type                                                          0
# drop_off_type                                                        0
# shape_dist_traveled                                                  0
# d_time                                                        09:31:08
# d_stop                                       4835-20171218162726_v61.9
# d_sequence                                                           2
# o_time_sec                                                       34200
# d_time_sec                                                       34268
# duration                                                            68
# block_id                                                             0
# route_id                                    98502-20171218162726_v61.9
# direction_id                                                         1
# trip_headsign                                                    Orewa
# shape_id                                      818-20171218162726_v61.9
# service_id                             1985054051-20171218162726_v61.9
# route_long_name       HC Station to Orewa via Silverdale and Millwater
# route_type                                                         Bus
# route_text_color                                                     0
# agency_id                                                        NZBNS
# route_color                                                          0
# route_short_name                                                   985
# stop_seq             4835-20171218162726_v61.9;4502-20171218162726_...
# o_stop_lat                                                    -36.6243
# o_stop_lon                                                     174.668
# d_stop_lat                                                    -36.6227
# d_stop_lon                                                     174.668
# freq                                                                 1
# awt                                                               1800
#
#                                                                      1
# trip_id                                1985054051-20171218162726_v61.9
# o_time                                                        09:31:08
# departure_time                                                09:31:08
# o_stop                                       4835-20171218162726_v61.9
# o_sequence                                                           2
# stop_headsign                                                        0
# pickup_type                                                          0
# drop_off_type                                                        0
# shape_dist_traveled                                                  0
# d_time                                                        09:32:16
# d_stop                                       4502-20171218162726_v61.9
# d_sequence                                                           3
# o_time_sec                                                       34268
# d_time_sec                                                       34336
# duration                                                            68
# block_id                                                             0
# route_id                                    98502-20171218162726_v61.9
# direction_id                                                         1
# trip_headsign                                                    Orewa
# shape_id                                      818-20171218162726_v61.9
# service_id                             1985054051-20171218162726_v61.9
# route_long_name       HC Station to Orewa via Silverdale and Millwater
# route_type                                                         Bus
# route_text_color                                                     0
# agency_id                                                        NZBNS
# route_color                                                          0
# route_short_name                                                   985
# stop_seq             4502-20171218162726_v61.9;4501-20171218162726_...
# o_stop_lat                                                    -36.6227
# o_stop_lon                                                     174.668
# d_stop_lat                                                    -36.6175
# d_stop_lon                                                     174.677
# freq                                                                 1
# awt                                                               1800

# %%
od_matrix = od_matrix.merge(
    pt_edges[['trip_id', 'o_stop', 'awt']], 
    left_on = ['trip_id', 'from_name'],
    right_on = ['trip_id', 'o_stop'],
    how='left').drop('o_stop', axis = 1)
od_matrix.head(2).T
# Out:
#                                                            0  \
# trip_name                              from 505601 to 505602
# leg_id                                                     0
# mode                                                    WALK
# from            POINT (174.4870233410001 -36.76534420899998)
# from_name                                             Origin
# to                               POINT (174.49168 -36.76922)
# to_name                          1:4876-20171218162726_v61.9
# route_id
# trip_id
# distance                                             277.777
# duration                                                 216
# startTime                                      1515610839000
# endTime                                        1515611055000
# waitTime                                                1000
# geometry   LINESTRING (17.449131 -3.676767, 17.449142 -3....
# awt_x                                                    NaN
# awt_y                                                    NaN
#
#                                                            1
# trip_name                              from 505601 to 505602
# leg_id                                                     1
# mode                                                     BUS
# from                             POINT (174.49168 -36.76922)
# from_name                          4876-20171218162726_v61.9
# to                               POINT (174.54584 -36.77235)
# to_name                          1:4868-20171218162726_v61.9
# route_id                        1:12503-20171218162726_v61.9
# trip_id                      1120107361-20171218162726_v61.9
# distance                                             4949.04
# duration                                                 343
# startTime                                      1515611056000
# endTime                                        1515611399000
# waitTime                                                1000
# geometry   LINESTRING (17.449168 -3.676922, 17.449169 -3....
# awt_x                                                   1800
# awt_y                                                   1800

# %%
#convert to number
od_matrix[['duration', 'distance', 'waitTime']]=od_matrix[['duration', 'distance', 'waitTime']].apply(pd.to_numeric)
od_matrix['duration'] = od_matrix['duration']/60
od_matrix['waitTime'] = od_matrix['waitTime']/1000/60
od_matrix['awt'] = od_matrix['awt']/60
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'awt'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-c9a692672959> in <module>()
#       3 od_matrix['duration'] = od_matrix['duration']/60
#       4 od_matrix['waitTime'] = od_matrix['waitTime']/1000/60
# ----> 5 od_matrix['awt'] = od_matrix['awt']/60
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\geopandas\geodataframe.py in __getitem__(self, key)
#     396         GeoDataFrame.
#     397         """
# --> 398         result = super(GeoDataFrame, self).__getitem__(key)
#     399         geo_col = self._geometry_column_name
#     400         if isinstance(key, string_types) and key == geo_col:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'awt'

# %%
od_matrix[od_matrix['trip_name']=='from 1695 to 1702'].T

# %% [markdown]
# ## Summarise with necessary fields

# %%
od_summary = pd.pivot_table(
    od_matrix, 
    index=['trip_name'], 
    values=['duration', 'distance', 'waitTime', 'awt'],
    columns=['mode'], 
    aggfunc=[np.sum],
    fill_value=0).reset_index()
od_summary['from']= od_summary.trip_name.apply(lambda x: x.split()[1])
od_summary['to']= od_summary.trip_name.apply(lambda x: x.split()[3])
od_summary['invehicle_time']= (od_summary[('sum', 'duration', 'BUS')]+
                                od_summary[('sum', 'duration', 'FERRY')]+
                                od_summary[('sum', 'duration', 'RAIL')])

od_summary['walk_time']= (od_summary[('sum', 'duration', 'WALK')])

od_summary['waitTime']= (od_summary[('sum', 'waitTime', 'BUS')]+
                         od_summary[('sum', 'waitTime', 'FERRY')]+
                         od_summary[('sum', 'waitTime', 'RAIL')])

od_summary['awt']= (od_summary[('sum', 'awt', 'BUS')]+
                         od_summary[('sum', 'awt', 'FERRY')]+
                         od_summary[('sum', 'awt', 'RAIL')])

od_summary['awt_travel_time']= (od_summary['invehicle_time']+
                                (od_summary['awt']/2))


pow_df = in_gdf.copy()
pow_df.columns = pd.MultiIndex.from_product([['sum'], [''], pow_df.columns])
od_summary = od_summary.merge(
    pow_df[[('sum', '', 'Unique_ID'), ('sum', '', 'P_O_W')]], 
    left_on = ['to'],
    right_on = [('sum', '','Unique_ID')],
    how='left').drop(('sum', '','Unique_ID'), axis = 1)

od_summary.head()

# %% [markdown]
# ## Distance decay

# %%
od_summary['dist_decay_45min'] = od_summary['awt_travel_time'].apply(lambda x: 1/(1+math.exp(0.2*(x-45))) )*od_summary[('sum', '', 'P_O_W')]

for i in range(5, 55, 5):
    f_name = 'dist_decay_{0}_improved'.format(i)
    od_summary['tt'] = (od_summary['invehicle_time']+
                        (od_summary['awt']*(1-i/100)/2))
    od_summary[f_name] = od_summary['tt'].apply(lambda x: 1/(1+math.exp(0.2*(x-45))) )*od_summary[('sum', '', 'P_O_W')]

od_summary.head().T

# %%
#od_summary['awt_frequent'] = od_summary['awt'].apply(lambda x: x if x < 15 else 15)
#od_summary['tt'] = (od_summary['invehicle_time']+ (od_summary['awt_frequent']/2))
#od_summary['dist_decay_all_frequent'] = od_summary['tt'].apply(lambda x: 1/(1+math.exp(0.2*(x-45))) )*od_summary[('sum', '', 'P_O_W')]
#od_summary.head(1).T

# %%
f_names = dict()
f_names['dist_decay_45min'] = 'sum'
for i in range(5, 55, 5):
    f_names['dist_decay_{0}_improved'.format(i)] = 'sum'
    
Hex_dist_decay_summary = od_summary.groupby('from', as_index=False).agg(f_names)
Hex_dist_decay_summary.to_csv(str(OUT_DIR/'Brisbane_Hex_dist_decay_summary.csv'))
Hex_dist_decay_summary.head()

# %%
## Cut off accessibility
